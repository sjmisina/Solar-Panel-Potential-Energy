# %%
import pandas as pd
from pathlib import Path
from datetime import datetime as dt

# %%
# Loading the preprocessed iris dataset
nisturl = "https://raw.githubusercontent.com/jpburgess/Solar-Panel-Potential-Energy/main/Resources/Datasets/NIST_Dataset.csv"
nist_df = pd.read_csv(nisturl)
nist_df

url = "https://raw.githubusercontent.com/jpburgess/Solar-Panel-Potential-Energy/main/Resources/Datasets/NREL_data_2015.csv"

url1 = "https://raw.githubusercontent.com/jpburgess/Solar-Panel-Potential-Energy/main/Resources/Datasets/NREL_data_2016.csv"

url2 = "https://raw.githubusercontent.com/jpburgess/Solar-Panel-Potential-Energy/main/Resources/Datasets/NREL_data_2017.csv"

url3 = "https://raw.githubusercontent.com/jpburgess/Solar-Panel-Potential-Energy/main/Resources/Datasets/NREL_data_2018.csv"

solar_nrel_2015 = pd.read_csv(url)
solar_nrel_2016 = pd.read_csv(url1)
solar_nrel_2017 = pd.read_csv(url2)
solar_nrel_2018 = pd.read_csv(url3)

# %%
solar_nrel_2015.dtypes
# Out:
# TIMESTAMP              object
# Year                    int64
# Month                   int64
# Day                     int64
# Hour                    int64
# Minute                  int64
# GHI                     int64
# DHI                     int64
# DNI                     int64
# Wind Speed            float64
# Temperature             int64
# Cloud Type              int64
# Solar Zenith Angle    float64
# Surface Albedo        float64
# Wind Direction        float64
# Pressure                int64
# Relative Humidity     float64
# Precipitable Water    float64
# dtype: object

# %%
solar_nrel_2015["TIMESTAMP"] = pd.to_datetime(solar_nrel_2015["TIMESTAMP"])
solar_nrel_2016["TIMESTAMP"] = pd.to_datetime(solar_nrel_2016["TIMESTAMP"])
solar_nrel_2017["TIMESTAMP"] = pd.to_datetime(solar_nrel_2017["TIMESTAMP"])
solar_nrel_2018["TIMESTAMP"] = pd.to_datetime(solar_nrel_2018["TIMESTAMP"])

solar_nrel_2015["TIMESTAMP"] = solar_nrel_2015.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
solar_nrel_2016["TIMESTAMP"] = solar_nrel_2016.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
solar_nrel_2017["TIMESTAMP"] = solar_nrel_2017.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
solar_nrel_2018["TIMESTAMP"] = solar_nrel_2018.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")

solar_nrel_2015["TIMESTAMP"] = pd.to_datetime(solar_nrel_2015["TIMESTAMP"])
solar_nrel_2016["TIMESTAMP"] = pd.to_datetime(solar_nrel_2016["TIMESTAMP"])
solar_nrel_2017["TIMESTAMP"] = pd.to_datetime(solar_nrel_2017["TIMESTAMP"])
solar_nrel_2018["TIMESTAMP"] = pd.to_datetime(solar_nrel_2018["TIMESTAMP"])

# %%
solar_nrel_2015.dtypes
# Out:
# TIMESTAMP             datetime64[ns]
# Year                           int64
# Month                          int64
# Day                            int64
# Hour                           int64
# Minute                         int64
# GHI                            int64
# DHI                            int64
# DNI                            int64
# Wind Speed                   float64
# Temperature                    int64
# Cloud Type                     int64
# Solar Zenith Angle           float64
# Surface Albedo               float64
# Wind Direction               float64
# Pressure                       int64
# Relative Humidity            float64
# Precipitable Water           float64
# dtype: object

# %%
# solar_nrel_2015.to_csv("solar_nrel_2015.csv", index = False)
# solar_nrel_2016.to_csv("solar_nrel_2016.csv", index = False)
# solar_nrel_2017.to_csv("solar_nrel_2017.csv", index = False)
# solar_nrel_2018.to_csv("solar_nrel_2018.csv", index = False)

# %% [markdown]
# # NIST PREPROCESSING

# %%
nist_df
# Out:
#                   TIMESTAMP  InvVDCin_Avg  Array Tilt
# 0       2015-01-01 00:00:00        20.910           5
# 1       2015-01-01 00:30:00        21.000           5
# 2       2015-01-01 01:00:00        20.990           5
# 3       2015-01-01 01:30:00        21.030           5
# 4       2015-01-01 02:00:00        20.960           5
# ...                     ...           ...         ...
# 191365  2018-03-18 21:30:00        -1.717          10
# 191366  2018-03-18 22:00:00        -1.900          10
# 191367  2018-03-18 22:30:00        -1.317          10
# 191368  2018-03-18 23:00:00        -1.700          10
# 191369  2018-03-18 23:30:00        -1.767          10
#
# [191370 rows x 3 columns]

# %%
nist_df.dtypes
# Out:
# TIMESTAMP        object
# InvVDCin_Avg    float64
# Array Tilt        int64
# dtype: object

# %%
t = "(2015)-(\d{2})-(\d{2})(\s)(\d{2}):(\d{2}):(\d{2})"
nist_2015 = nist_df[nist_df["TIMESTAMP"].str.contains(t)]
t = "(2016)-(\d{2})-(\d{2})(\s)(\d{2}):(\d{2}):(\d{2})"
nist_2016 = nist_df[nist_df["TIMESTAMP"].str.contains(t)]
t = "(2017)-(\d{2})-(\d{2})(\s)(\d{2}):(\d{2}):(\d{2})"
nist_2017 = nist_df[nist_df["TIMESTAMP"].str.contains(t)]
t = "(2018)-(\d{2})-(\d{2})(\s)(\d{2}):(\d{2}):(\d{2})"
nist_2018 = nist_df[nist_df["TIMESTAMP"].str.contains(t)]
# Out:
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
canopy_nist_2015 = nist_2015[nist_2015["Array Tilt"]==5]
roof_nist_2015 = nist_2015[nist_2015["Array Tilt"]==10]
ground_nist_2015 = nist_2015[nist_2015["Array Tilt"]==20]

canopy_nist_2016 = nist_2016[nist_2016["Array Tilt"]==5]
roof_nist_2016 = nist_2016[nist_2016["Array Tilt"]==10]
ground_nist_2016 = nist_2016[nist_2016["Array Tilt"]==20]

canopy_nist_2017 = nist_2017[nist_2017["Array Tilt"]==5]
roof_nist_2017 = nist_2017[nist_2017["Array Tilt"]==10]
ground_nist_2017 = nist_2017[nist_2017["Array Tilt"]==20]

canopy_nist_2018 = nist_2018[nist_2018["Array Tilt"]==5]
roof_nist_2018 = nist_2018[nist_2018["Array Tilt"]==10]
ground_nist_2018 = nist_2018[nist_2018["Array Tilt"]==20]

# %%
ground_nist_2018.tail()
# Out:
#                   TIMESTAMP  InvVDCin_Avg  Array Tilt
# 135719  2018-12-31 21:30:00         10.05          20
# 135720  2018-12-31 22:00:00         10.55          20
# 135721  2018-12-31 22:30:00          9.78          20
# 135722  2018-12-31 23:00:00         10.26          20
# 135723  2018-12-31 23:30:00          9.43          20

# %%
roof_nist_2018.shape # Found a discrepancy
# Out:
# (3644, 3)

# %%
canopy_nist_2015.dtypes
# Out:
# TIMESTAMP        object
# InvVDCin_Avg    float64
# Array Tilt        int64
# dtype: object

# %%
canopy_nist_2015["TIMESTAMP"] = pd.to_datetime(canopy_nist_2015["TIMESTAMP"])
ground_nist_2015["TIMESTAMP"] = pd.to_datetime(ground_nist_2015["TIMESTAMP"])
roof_nist_2015["TIMESTAMP"] = pd.to_datetime(roof_nist_2015["TIMESTAMP"])

canopy_nist_2016["TIMESTAMP"] = pd.to_datetime(canopy_nist_2016["TIMESTAMP"])
ground_nist_2016["TIMESTAMP"] = pd.to_datetime(ground_nist_2016["TIMESTAMP"])
roof_nist_2016["TIMESTAMP"] = pd.to_datetime(roof_nist_2016["TIMESTAMP"])

canopy_nist_2017["TIMESTAMP"] = pd.to_datetime(canopy_nist_2017["TIMESTAMP"])
ground_nist_2017["TIMESTAMP"] = pd.to_datetime(ground_nist_2017["TIMESTAMP"])
roof_nist_2017["TIMESTAMP"] = pd.to_datetime(roof_nist_2017["TIMESTAMP"])

canopy_nist_2018["TIMESTAMP"] = pd.to_datetime(canopy_nist_2018["TIMESTAMP"])
ground_nist_2018["TIMESTAMP"] = pd.to_datetime(ground_nist_2018["TIMESTAMP"])
roof_nist_2018["TIMESTAMP"] = pd.to_datetime(roof_nist_2018["TIMESTAMP"])
# Out:
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
canopy_nist_2015["TIMESTAMP"] = canopy_nist_2015.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
ground_nist_2015["TIMESTAMP"] = ground_nist_2015.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
roof_nist_2015["TIMESTAMP"] = roof_nist_2015.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")

canopy_nist_2016["TIMESTAMP"] = canopy_nist_2016.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
ground_nist_2016["TIMESTAMP"] = ground_nist_2016.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
roof_nist_2016["TIMESTAMP"] = roof_nist_2016.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")

canopy_nist_2017["TIMESTAMP"] = canopy_nist_2017.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
ground_nist_2017["TIMESTAMP"] = ground_nist_2017.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
roof_nist_2017["TIMESTAMP"] = roof_nist_2017.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")

canopy_nist_2018["TIMESTAMP"] = canopy_nist_2018.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
ground_nist_2018["TIMESTAMP"] = ground_nist_2018.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
roof_nist_2018["TIMESTAMP"] = roof_nist_2018.TIMESTAMP.dt.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
canopy_nist_2015["TIMESTAMP"] = pd.to_datetime(canopy_nist_2015["TIMESTAMP"])
ground_nist_2015["TIMESTAMP"] = pd.to_datetime(ground_nist_2015["TIMESTAMP"])
roof_nist_2015["TIMESTAMP"] = pd.to_datetime(roof_nist_2015["TIMESTAMP"])

canopy_nist_2016["TIMESTAMP"] = pd.to_datetime(canopy_nist_2016["TIMESTAMP"])
ground_nist_2016["TIMESTAMP"] = pd.to_datetime(ground_nist_2016["TIMESTAMP"])
roof_nist_2016["TIMESTAMP"] = pd.to_datetime(roof_nist_2016["TIMESTAMP"])

canopy_nist_2017["TIMESTAMP"] = pd.to_datetime(canopy_nist_2017["TIMESTAMP"])
ground_nist_2017["TIMESTAMP"] = pd.to_datetime(ground_nist_2017["TIMESTAMP"])
roof_nist_2017["TIMESTAMP"] = pd.to_datetime(roof_nist_2017["TIMESTAMP"])

canopy_nist_2018["TIMESTAMP"] = pd.to_datetime(canopy_nist_2018["TIMESTAMP"])
ground_nist_2018["TIMESTAMP"] = pd.to_datetime(ground_nist_2018["TIMESTAMP"])
roof_nist_2018["TIMESTAMP"] = pd.to_datetime(roof_nist_2018["TIMESTAMP"])
# Out:
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\2ainm\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
canopy_nist_2015.dtypes
# Out:
# TIMESTAMP       datetime64[ns]
# InvVDCin_Avg           float64
# Array Tilt               int64
# dtype: object

# %%
# canopy_nist_2015.to_csv("canopy_nist_2015.csv", index = False)
# ground_nist_2015.to_csv("ground_nist_2015.csv", index = False)
# roof_nist_2015.to_csv("roof_nist_2015.csv", index = False)

# canopy_nist_2016.to_csv("canopy_nist_2016.csv", index = False)
# ground_nist_2016.to_csv("ground_nist_2016.csv", index = False)
# roof_nist_2016.to_csv("roof_nist_2016.csv", index = False)

# canopy_nist_2017.to_csv("canopy_nist_2017.csv", index = False)
# ground_nist_2017.to_csv("ground_nist_2017.csv", index = False)
# roof_nist_2017.to_csv("roof_nist_2017.csv", index = False)

# canopy_nist_2018.to_csv("canopy_nist_2018.csv", index = False)
# ground_nist_2018.to_csv("ground_nist_2018.csv", index = False)
# roof_nist_2018.to_csv("roof_nist_2018.csv", index = False)

# %%
solar_canopy_2015 = pd.merge(canopy_nist_2015, solar_nrel_2015, on='TIMESTAMP', how='left')
solar_canopy_2016 = pd.merge(canopy_nist_2016, solar_nrel_2016, on='TIMESTAMP', how='left')
solar_canopy_2017 = pd.merge(canopy_nist_2017, solar_nrel_2017, on='TIMESTAMP', how='left')
solar_canopy_2018 = pd.merge(canopy_nist_2018, solar_nrel_2018, on='TIMESTAMP', how='left')

solar_ground_2015 = pd.merge(ground_nist_2015, solar_nrel_2015, on='TIMESTAMP', how='left')
solar_ground_2016 = pd.merge(ground_nist_2016, solar_nrel_2016, on='TIMESTAMP', how='left')
solar_ground_2017 = pd.merge(ground_nist_2017, solar_nrel_2017, on='TIMESTAMP', how='left')
solar_ground_2018 = pd.merge(ground_nist_2018, solar_nrel_2018, on='TIMESTAMP', how='left')

solar_roof_2015 = pd.merge(roof_nist_2015, solar_nrel_2015, on='TIMESTAMP', how='left')
solar_roof_2016 = pd.merge(roof_nist_2016, solar_nrel_2016, on='TIMESTAMP', how='left')
solar_roof_2017 = pd.merge(roof_nist_2017, solar_nrel_2017, on='TIMESTAMP', how='left')
solar_roof_2018 = pd.merge(roof_nist_2018, solar_nrel_2018, on='TIMESTAMP', how='left')

# %%
solar_canopy_2015 = solar_canopy_2015.dropna()
solar_canopy_2016 = solar_canopy_2016.dropna()
solar_canopy_2017 = solar_canopy_2017.dropna()
solar_canopy_2018 = solar_canopy_2018.dropna()

solar_ground_2015 = solar_ground_2015.dropna()
solar_ground_2016 = solar_ground_2016.dropna()
solar_ground_2017 = solar_ground_2017.dropna()
solar_ground_2018 = solar_ground_2018.dropna()

solar_roof_2015 = solar_roof_2015.dropna() 
solar_roof_2016 = solar_roof_2016.dropna() 
solar_roof_2017 = solar_roof_2017.dropna() 
solar_roof_2018 = solar_roof_2018.dropna()

# %%
solar_canopy_2015.to_csv("solar_canopy_2015.csv", index = False)
solar_canopy_2016.to_csv("solar_canopy_2016.csv", index = False)
solar_canopy_2017.to_csv("solar_canopy_2017.csv", index = False)
solar_canopy_2018.to_csv("solar_canopy_2018.csv", index = False)

solar_ground_2015.to_csv("solar_ground_2015.csv", index = False)
solar_ground_2016.to_csv("solar_ground_2016.csv", index = False)
solar_ground_2017.to_csv("solar_ground_2017.csv", index = False)
solar_ground_2018.to_csv("solar_ground_2018.csv", index = False)

solar_roof_2015.to_csv("solar_roof_2015.csv", index = False)
solar_roof_2016.to_csv("solar_roof_2016.csv", index = False)
solar_roof_2017.to_csv("solar_roof_2017.csv", index = False)
solar_roof_2018.to_csv("solar_roof_2018.csv", index = False)

# %%
solar_roof_2018.tail()
# Out:
#                TIMESTAMP  InvVDCin_Avg  Array Tilt    Year  Month   Day  Hour  \
# 3639 2018-03-18 21:30:00        -1.717          10  2018.0    3.0  18.0  21.0
# 3640 2018-03-18 22:00:00        -1.900          10  2018.0    3.0  18.0  22.0
# 3641 2018-03-18 22:30:00        -1.317          10  2018.0    3.0  18.0  22.0
# 3642 2018-03-18 23:00:00        -1.700          10  2018.0    3.0  18.0  23.0
# 3643 2018-03-18 23:30:00        -1.767          10  2018.0    3.0  18.0  23.0
#
#       Minute  GHI  DHI  DNI  Wind Speed  Temperature  Cloud Type  \
# 3639    30.0  0.0  0.0  0.0         1.2          3.7         0.0
# 3640     0.0  0.0  0.0  0.0         1.2          3.1         0.0
# 3641    30.0  0.0  0.0  0.0         1.3          2.6         0.0
# 3642     0.0  0.0  0.0  0.0         1.3          2.1         0.0
# 3643    30.0  0.0  0.0  0.0         1.3          1.8         0.0
#
#       Solar Zenith Angle  Surface Albedo  Wind Direction  Pressure  \
# ...
